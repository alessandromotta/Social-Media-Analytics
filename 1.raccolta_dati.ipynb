# %% [markdown]
# **creazione dataset di partenza**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df5_11=pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Tweet_Vax_5_to_11.csv')
df15= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Vax_tweet_15.csv')
df16= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Vax_tweet_16.csv')
df17= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Vax_tweet_17.csv', lineterminator='\n')
df18= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Vax_tweet_18.csv')
df19= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Vax_tweet_19.csv')
df21= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Tweet_Vax21.csv')
#df15= pd.read_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/Vax_tweet_15.csv')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,3,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print(len(df5_11),
      len(df15),
      len(df16),
      len(df17),
      len(df18),
      len(df19),
      len(df21),
      'totale di', len(df5_11)+len(df15)+len(df16)+len(df17)+len(df18)+len(df19)+len(df21), 'righe')
# Out:
# 523352 89718 36952 25266 38637 89431 41716 totale di 845072 righe

# %%
parti=[df5_11,df15, df16, df17, df18, df19, df21]
df_tweet_completo=pd.concat(parti)

# %%
len(df_tweet_completo)
# Out:
# 845072

# %%
df_tweet_completo.head()
# Out:
#   Unnamed: 0                       _id  ...                 username entities
# 0          0  5fcbb341ce2a8e9b3d4d23f3  ...            Bruce Pelland      NaN
# 1          1  5fcbb341ce2a8e9b3d4d23f4  ...     Sohail Ahmad🇵🇰🇹🇷🇦🇿🇨🇳      NaN
# 2          2  5fcbb341ce2a8e9b3d4d23f5  ...       ❌❌❌ΛПӨПCΛ§§I⭐️⭐️⭐️      NaN
# 3          3  5fcbb341ce2a8e9b3d4d23f6  ...             sandra rouse      NaN
# 4          4  5fcbb342ce2a8e9b3d4d23f7  ...  Die maskierte Manderine      NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# **CLEANING INIZIALE**

# %%
#filtro righe che non hanno text e username vuoto
df_tweet_completo=df_tweet_completo[(df_tweet_completo['text'].notna()) | df_tweet_completo['username'].notna()]

# %%
#elimino righe che hanno text minore di 10 caratteri
df_tweet_completo=df_tweet_completo[[len(x)>10 for x in df_tweet_completo['text']]]

# %%
len(df_tweet_completo)
# Out:
# 838611

# %% [markdown]
# **SCARICO IL DATASET**

# %%
df_tweet_completo.to_csv('/content/drive/MyDrive/SMA/Tweets_Nostri/df_tweet_completo.csv')
