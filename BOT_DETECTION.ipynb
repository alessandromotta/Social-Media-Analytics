# %% [markdown]
# # BOT DETECTION

# %%
import tweepy
import csv
import pandas as pd
# Used for progress bar
import time
import sys

# %%
#df2=pd.read_csv('/Users/alessandromotta/Downloads/file.csv', encoding='utf8')
df2=pd.read_csv("/content/drive/MyDrive/SMA/Tweets Nostri/df_tweet_completo.csv")
df2.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0,1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   Unnamed: 0 Unnamed: 0.1  ...       user_id               username
# 0          0            0  ...  8.859092e+06  Portland Press Herald
# 1          1            1  ...  3.818868e+08             Tim Miller
# 2          2            2  ...  4.502883e+08                 alyssa
# 3          3            3  ...  1.158591e+18              MD Robles
# 4          4            4  ...  4.895070e+08      Craig M. Wax D.O.
#
# [5 rows x 9 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
rapid_key = "8a34684f01msh7d2f1c4465a37e4p14dd14jsnad24720f7a45"
twitter_app_auth = {
    'consumer_key':"eROgi5E9cCHSWO8A2dUZw5tD4",
    'consumer_secret' : "RIUGtAICRdGiUrmLVsbFkbe36oROJd5NFVVHGhiGPba5bYGhEQ",
    'access_token' : "1204688941594611712-OVpY1GbNv5Ue8Tg56L4hfWYVzTCVBT",
    'access_token_secret' : "27dhSY2EpDZs1Bqp66Kp7o2E4awgMHdIC9y4jrId7ebU5",
  }

botometer_api_url = "https://botometer-pro.p.rapidapi.com"

# %%
#pip install botometer

# %%
from botometer import Botometer
bom = Botometer(wait_on_ratelimit=True,
                          rapidapi_key=rapid_key,
                          **twitter_app_auth,
               botometer_api_url=botometer_api_url)

# %%
check_bot = []
conta = 0
name_list = []

# %%
df2=df2[(df2['text'].notna()) | df2['username'].notna()]

# %%
for i in df2.username.drop_duplicates()[4000:12627]:
    try:
        name_account = '@'+i
        print(conta,name_account)
        result = bom.check_account(name_account)
        check_bot.append(result["cap"])
        name_list.append(i)
        if conta % 100 == 0:
            print(conta)
        conta += 1
    except tweepy.TweepError as ex:
            if (ex.reason == "Not authorized."):
                
                print('Not authorized.')
                pass
# Out:
# 0 @wandavision
# 0
# 1 @Esheksha
# ---------------------------------------------------------------------------
# NoTimelineError                           Traceback (most recent call last)
# <ipython-input-17-7d959c5b2da0> in <module>()
#       3         name_account = '@'+i
#       4         print(conta,name_account)
# ----> 5         result = bom.check_account(name_account)
#       6         check_bot.append(result["cap"])
#       7         name_list.append(i)
#
# /usr/local/lib/python3.6/dist-packages/botometer/__init__.py in check_account(self, user, full_user_object)
#     127                                          full_user_object=full_user_object)
#     128         if not payload['timeline']:
# --> 129             raise NoTimelineError(payload['user'])
#     130
#     131         url = self.bom_api_path('check_account')
#
# NoTimelineError: user '{'id_str': '252521157', 'screen_name': 'esheksha'}' has no tweets in timeline

# %%
result

check_bot 

df.screen_name.drop_duplicates()

app1 =  pd.DataFrame(check_bot)
aap = pd.DataFrame(name_list)
final = pd.concat([app1,aap], axis = 1)

final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-49345b683a21> in <module>()
#       3 check_bot
#       4
# ----> 5 df.screen_name.drop_duplicates()
#       6
#       7 app1 =  pd.DataFrame(check_bot)
#
# NameError: name 'df' is not defined
